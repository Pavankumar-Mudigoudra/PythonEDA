# %% [markdown]
# # Exploratory Data Analysis on YouTube data.
# Domain: Social media

# %% [markdown]
# # 1. Import required libraries and read the provided dataset  and retrieve top 5 and bottom 5 records.

# %%
#importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('youtube_dislike_dataset.csv')

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# # 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
df.shape
# Out:
# (37422, 12)

# %% [markdown]
# # Inference:
#  * The dataset consists of 37422 records having 12 attributes of which 8 are object datatypes and 4 integer datatypes all the attributes accept comments are non-null.

# %%
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %% [markdown]
# # 3. Check for the Percentage of the missing values and drop or impute them.

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
df=df.dropna()
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
df.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# # 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df.describe(include='all')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     zxCoxtPOJj8    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# mean            NaN    NaN                       NaN                  NaN
# std             NaN    NaN                       NaN                  NaN
# min             NaN    NaN                       NaN                  NaN
# 25%             NaN    NaN                       NaN                  NaN
# 50%             NaN    NaN                       NaN                  NaN
# 75%             NaN    NaN                       NaN                  NaN
# max             NaN    NaN                       NaN                  NaN
#
#                published_at    view_count         likes      dislikes  \
# ...

# %% [markdown]
# # Inference
# The stastical summary for the categorical data is of no meaning because it doesnt provide any valuable
# output in terms of numbers
#
# The stastical summary of the Numerical data gives the five number summary output which helps in the further assessment where we can remove the outliers and scale the dataset which will provide a valuable content.

# %% [markdown]
# # 5. Convert datatype of column published_at from object to pandas datetime.

# %%
df['published_at']
# Out:
# 0        2021-07-01 10:00:00
# 1        2021-06-10 16:00:00
# 2        2021-09-20 01:03:32
# 3        2021-03-03 10:00:17
# 4        2021-12-07 13:00:00
#                 ...
# 37417    2021-02-12 05:03:49
# 37418    2021-01-16 05:39:05
# 37419    2021-06-02 09:00:10
# 37420    2020-10-20 20:59:30
# 37421    2021-05-23 21:00:31
# Name: published_at, Length: 37264, dtype: object

# %%
np.dtype(df.published_at)
# Out:
# dtype('O')

# %%
df['published_at']=pd.DataFrame(pd.to_datetime(df['published_at']))

# %%
np.dtype(df.published_at)
# Out:
# dtype('<M8[ns]')

# %%
df['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37264, dtype: datetime64[ns]

# %% [markdown]
# # 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_month']=df['published_at'].dt.month

# %%
df['published_month']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37264, dtype: int64

# %% [markdown]
# # 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
month={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Num',12:'Dec'}
month
# Out:
# {1: 'Jan',
#  2: 'Feb',
#  3: 'Mar',
#  4: 'Apr',
#  5: 'May',
#  6: 'Jun',
#  7: 'Jul',
#  8: 'Aug',
#  9: 'Sep',
#  10: 'Oct',
#  11: 'Num',
#  12: 'Dec'}

# %%
df['published_month']=df['published_month'].map(month)
df['published_month']
# Out:
# 0        Jul
# 1        Jun
# 2        Sep
# 3        Mar
# 4        Dec
#         ...
# 37417    Feb
# 37418    Jan
# 37419    Jun
# 37420    Oct
# 37421    May
# Name: published_month, Length: 37264, dtype: object

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 8.Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
df.groupby('published_month')['video_id'].count().sort_values(ascending=False)
# Out:
# published_month
# Oct    4976
# Sep    4854
# Num    4821
# Aug    4250
# Dec    3063
# Jul    2331
# Jun    2305
# Mar    2248
# Feb    2125
# Apr    2119
# Jan    2099
# May    2073
# Name: video_id, dtype: int64

# %% [markdown]
# # 9. Find the count of unique video_id, channel_id and channel_title.

# %%
df['video_id'].nunique()
# Out:
# 37264

# %%
df['channel_id'].nunique()
# Out:
# 10891

# %%
df['channel_title'].nunique()
# Out:
# 10813

# %% [markdown]
# # 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
pd.DataFrame(df.groupby('channel_title')['video_id'].count().sort_values(ascending=False).head(10))
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
pd.DataFrame(df.groupby('channel_title')['video_id'].count().sort_values(ascending=False).tail(10))
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %% [markdown]
# # 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
df.groupby(['channel_title','title'])['likes'].max().sort_values(ascending=False).head(1)
# Out:
# channel_title  title
# HYBE LABELS    BTS () 'Dynamite' Official MV    31837675
# Name: likes, dtype: int64

# %%
df.groupby(['channel_title','title'])['likes'].min().sort_values().head(1)
# Out:
# channel_title  title
# Circle K       Leading the Charge | Circle K    22
# Name: likes, dtype: int64

# %% [markdown]
# # Inference
#  From the dataset we can see that the video with title name "BTS() 'Dynamite' Official MV" from channel "HYBE LABELS"  has got maximum number of likes i.e, 31,837,675
#
# And video with title name " Leading the Charge " from channel "Circle K" has the least number of likes i.e, 22

# %% [markdown]
# # 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
df.groupby('title')['dislikes'].max().sort_values(ascending=False).head(1)
# Out:
# title
# Cuties | Official Trailer | Netflix    2397733
# Name: dislikes, dtype: int64

# %%
df.groupby('title')['dislikes'].min().sort_values().head(1)
# Out:
# title
# Tims For Good: A Taste Of The Familiar    3
# Name: dislikes, dtype: int64

# %% [markdown]
# # Inference
#  The video with the title name 'Cuties | Official Trailer | Netflix ' got the maximum number of dislikes about 2,397,733
#
# The video with the title name 'Tims For Good: A Taste Of The Familiar' got the minimum number of dislikes i.e, 3

# %% [markdown]
# # 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
df['dislike_count']=df['dislikes']/df['view_count']*100

# %%
plt.figure(figsize=[10,5])
plt.scatter(x=df['dislike_count'],y=df['view_count'])

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# * Yes the number of views have an effect on how many have disliked the video, it effects the viewing in future as if there are more dislikes then certain number then the user doesnot show interest to watch the correlation about 0.68 shows that it affects the viewing and viewer number

# %% [markdown]
# # 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
df[df['published_month']=='Jan']
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %% [markdown]
# about 2099 videos have been published In January

# %% [markdown]
#     ----------------------------------------************-----------------------------------------
